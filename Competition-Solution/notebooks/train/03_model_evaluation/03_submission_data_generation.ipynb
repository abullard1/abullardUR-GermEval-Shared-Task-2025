# %%
# Competition-Solution/notebooks/train/03_model_evaluation/03_submission_data_generation.ipynb

# %% [markdown]
# ### Submission Data Generation
#
# The notebooks within the **'03_model_evaluation'** folder perform the evaluation of a competition model based on the training dataset.
#
# This notebook performs the generation of the submission data for the competition in the correct format, specified by the competition organizers.
#
# The notebook generates a submission for each model in the `predictions_submissions` folder, and then zips them together into a single zip file.

# %%
import sys
from pathlib import Path

project_root = Path.cwd().parent.parent.parent
sys.path.append(str(project_root / "src"))

from generate_submission_results import create_submission_widget

# %%
create_submission_widget(project_root)
