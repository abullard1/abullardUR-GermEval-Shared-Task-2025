# %%
# Competition-Solution/notebooks/train/00_data_profiling/03_0_c2a_data_profiling_frequency_distribution.ipynb

# %% [markdown]
# ---

# %% [markdown]
# ##### <b>Imports</b>

# %%
import sys
from nltk.probability import FreqDist
from rich.console import Console

sys.path.append("../../../src")
import data_utils

console = Console()

# %% [markdown]
# ##### <b>Loading the data</b>

# %%
df_call2action, df_dbo, df_violence = data_utils.load_competition_data(data_dir="../../../data/raw/", type="train")
# Out:
# Loading competition data...
# Data of type 'train' loaded successfully.

# %% [markdown]
# ##### <b>Frequency Distribution (C2A)</b>

# %% [markdown]
# <p>Initializing NLTK</p>

# %%
data_utils.initialize_nltk()
# Out:
# Initializing NLTK...
# Resources will be downloaded to /home/samuel/nltk_data.
# ...
# NLTK initialized successfully.

# %% [markdown]
# <p><b>Preparing the data for frequency distribution analysis</b></p>

# %%
c2a_tokens, c2a_sentences = data_utils.prepare_data_for_frequency_distribution_analysis(df_call2action)
# Out:
# Preparing data for frequency distribution analysis...
# Preparing text string for frequency distribution analysis...
# Text prepared successfully.

# %% [markdown]
# ---

# %% [markdown]
# <p><b>C2A Frequency Distribution of the individual words (unfiltered)</b></p>
# <p><i><li>Bar Plot</li><i><p>

# %%
# Frequency Distribution of the individual tokens
c2a_freq_dist_unfiltered = FreqDist(c2a_tokens)

# Creates a dictionary with the frequency distribution of C2A
freq_dist_dict_unfiltered = {"C2A": c2a_freq_dist_unfiltered}

# Plots the frequency distribution as a bar plot
c2a_freq_dist_fig, c2a_freq_dist_ax = data_utils.create_frequency_distribution_plot(
    freq_dist_dict_unfiltered,
    title="C2A Frequency Word Distribution (unfiltered)", 
    n_words=30,
    figsize=(16, 10),
    column_names=["Word", "Frequency"],
    show_grid=True
)

# %% [markdown]
# <p><i><li>Line Plot</li><i><p>

# %%
# Frequency Distribution of the individual tokens
c2a_freq_dist_unfiltered = FreqDist(c2a_tokens)

# Creates a dictionary with the frequency distribution of C2A
freq_dist_dict_unfiltered = {"C2A": c2a_freq_dist_unfiltered}

# Plots the frequency distribution as a line plot
c2a_freq_dist_line_fig, c2a_freq_dist_line_ax = data_utils.create_frequency_distribution_line_plot(
    freq_dist_dict_unfiltered,
    title="C2A Frequency Word Distribution (unfiltered)", 
    n_words=30,
    figsize=(16, 10),
    column_names=["Word", "Frequency"],
    show_grid=True
)

# %% [markdown]
# <p><b>C2A Frequency Distribution of the individual words (filtered)</b></p>
# <p><i><li>Bar Plot</li><i><p>

# %%
# Removes stopwords from the tokens
c2a_filtered_words = data_utils.get_filtered_tokens(c2a_tokens)

# Frequency Distribution of the individual tokens
c2a_freq_dist_filtered = FreqDist(c2a_filtered_words)

# Creates a dictionary with the frequency distribution of C2A
freq_dist_dict_filtered = {"C2A": c2a_freq_dist_filtered}

# Plots the frequency distributions as a bar plot
c2a_freq_dist_fig, c2a_freq_dist_ax = data_utils.create_frequency_distribution_plot(
    freq_dist_dict_filtered,
    title="C2A Frequency Word Distribution (filtered)", 
    n_words=30,
    figsize=(16, 10),
    column_names=["Word", "Frequency"],
    show_grid=True
)

# %% [markdown]
# <p><i><li>Line Plot</li><i><p>

# %%
# Removes stopwords from the tokens
c2a_filtered_words = data_utils.get_filtered_tokens(c2a_tokens)

# Frequency Distribution of the individual tokens
c2a_freq_dist_filtered = FreqDist(c2a_filtered_words)

# Creates a dictionary with the frequency distribution of C2A
freq_dist_dict_filtered = {"C2A": c2a_freq_dist_filtered}

# Plots the frequency distribution as a line plot
c2a_freq_dist_line_fig, c2a_freq_dist_line_ax = data_utils.create_frequency_distribution_line_plot(
    freq_dist_dict_filtered,
    title="C2A Frequency Word Distribution (filtered)", 
    n_words=30,
    figsize=(16, 10),
    column_names=["Word", "Frequency"],
    show_grid=True
)

# %% [markdown]
# ---

# %% [markdown]
# <p><b>C2A Per Class Frequency Distribution of the individual words (unfiltered)</b></p>
# <p><i><li>Bar Plot</li><i><p>

# %%
# Gets the class corpuses
c2a_class_corpuses = data_utils.get_class_corpuses(df_call2action, "C2A")

# Tokenizes the class corpuses
c2a_true_tokens, c2a_true_sentences = data_utils.prepare_text_for_frequency_distribution_analysis(
    c2a_class_corpuses["C2A_true"]
)
c2a_false_tokens, c2a_false_sentences = data_utils.prepare_text_for_frequency_distribution_analysis(
    c2a_class_corpuses["C2A_false"]
)

# Creates the frequency distribution classes
c2a_true_freq_dist = FreqDist(c2a_true_tokens)
c2a_false_freq_dist = FreqDist(c2a_false_tokens)

# Creates a dictionary with the frequency distribution of the classes
freq_dist_dict_unfiltered = {"C2A_true": c2a_true_freq_dist, "C2A_false": c2a_false_freq_dist}

# Plots the frequency distributions as a bar plot
c2a_freq_dist_fig, c2a_freq_dist_ax = data_utils.create_frequency_distribution_plot(
    freq_dist_dict_unfiltered,
    title="C2A Frequency Word Distribution per Class (unfiltered)", 
    n_words=30,
    figsize=(16, 10),
    column_names=["Word", "Frequency"],
    show_grid=True
)
# Out:
# Creating class corpuses for C2A column...
#   - Found 6177 tweets for label 'False'
#   - Found 663 tweets for label 'True'
# Created 2 class corpuses successfully.
#   - C2A_false: ~139633 words
#   - C2A_true: ~23256 words
# Preparing text string for frequency distribution analysis...
# Text prepared successfully.
# Preparing text string for frequency distribution analysis...
# Text prepared successfully.

# %% [markdown]
# <p><i><li>Line Plot</li><i><p>

# %%
# Gets the class corpuses for the data
c2a_class_corpuses = data_utils.get_class_corpuses(df_call2action, "C2A")

# Tokenizes the class corpuses
c2a_true_tokens, c2a_true_sentences = data_utils.prepare_text_for_frequency_distribution_analysis(
    c2a_class_corpuses["C2A_true"]
)
c2a_false_tokens, c2a_false_sentences = data_utils.prepare_text_for_frequency_distribution_analysis(
    c2a_class_corpuses["C2A_false"]
)

# Creates the frequency distribution classes
c2a_true_freq_dist = FreqDist(c2a_true_tokens)
c2a_false_freq_dist = FreqDist(c2a_false_tokens)

# Creates a dictionary with the frequency distributions
freq_dist_dict_unfiltered = {"C2A_true": c2a_true_freq_dist, "C2A_false": c2a_false_freq_dist}

# Plots the frequency distribution as a line plot
c2a_freq_dist_line_fig, c2a_freq_dist_line_ax = data_utils.create_frequency_distribution_line_plot(
    freq_dist_dict_unfiltered,
    title="C2A Frequency Word Distribution per Class (unfiltered)", 
    n_words=30,
    figsize=(16, 10),
    column_names=["Word", "Frequency"],
    show_grid=True
)
# Out:
# Creating class corpuses for C2A column...
#   - Found 6177 tweets for label 'False'
#   - Found 663 tweets for label 'True'
# Created 2 class corpuses successfully.
#   - C2A_false: ~139633 words
#   - C2A_true: ~23256 words
# Preparing text string for frequency distribution analysis...
# Text prepared successfully.
# Preparing text string for frequency distribution analysis...
# Text prepared successfully.

# %% [markdown]
# <p><b>C2A Per Class Frequency Distribution of the individual words (filtered)</b></p>
# <p><i><li>Bar Plot</li><i><p>

# %%
# Gets the class corpuses for the data
c2a_class_corpuses = data_utils.get_class_corpuses(df_call2action, "C2A")

# Tokenizes the class corpuses
c2a_true_tokens, c2a_true_sentences = data_utils.prepare_text_for_frequency_distribution_analysis(
    c2a_class_corpuses["C2A_true"]
)
c2a_false_tokens, c2a_false_sentences = data_utils.prepare_text_for_frequency_distribution_analysis(
    c2a_class_corpuses["C2A_false"]
)

# Removes stopwords from the tokens
c2a_true_filtered = data_utils.get_filtered_tokens(c2a_true_tokens)
c2a_false_filtered = data_utils.get_filtered_tokens(c2a_false_tokens)

# Creates the frequency distribution classes
c2a_true_freq_dist_filtered = FreqDist(c2a_true_filtered)
c2a_false_freq_dist_filtered = FreqDist(c2a_false_filtered)

# Creates a dictionary with the frequency distribution of the classes
freq_dist_dict_filtered = {"C2A_true (filtered)": c2a_true_freq_dist_filtered, "C2A_false (filtered)": c2a_false_freq_dist_filtered}

# Plots the frequency distributions as a bar plot
c2a_filtered_freq_dist_fig, c2a_filtered_freq_dist_ax = data_utils.create_frequency_distribution_plot(
    freq_dist_dict_filtered,
    title="C2A Frequency Word Distribution per Class (filtered)", 
    n_words=30,
    figsize=(16, 10),
    column_names=["Word", "Frequency"],
    show_grid=True
)
# Out:
# Creating class corpuses for C2A column...
#   - Found 6177 tweets for label 'False'
#   - Found 663 tweets for label 'True'
# Created 2 class corpuses successfully.
#   - C2A_false: ~139633 words
#   - C2A_true: ~23256 words
# Preparing text string for frequency distribution analysis...
# Text prepared successfully.
# Preparing text string for frequency distribution analysis...
# Text prepared successfully.

# %% [markdown]
# <p><i><li>Line Plot</li><i><p>

# %%
# Gets the class corpuses for the data
c2a_class_corpuses = data_utils.get_class_corpuses(df_call2action, "C2A")

# Tokenizes the class corpuses
c2a_true_tokens, c2a_true_sentences = data_utils.prepare_text_for_frequency_distribution_analysis(
    c2a_class_corpuses["C2A_true"]
)
c2a_false_tokens, c2a_false_sentences = data_utils.prepare_text_for_frequency_distribution_analysis(
    c2a_class_corpuses["C2A_false"]
)

# Removes stopwords from the tokens
c2a_true_filtered = data_utils.get_filtered_tokens(c2a_true_tokens)
c2a_false_filtered = data_utils.get_filtered_tokens(c2a_false_tokens)

# Creates the frequency distribution classes
c2a_true_freq_dist_filtered = FreqDist(c2a_true_filtered)
c2a_false_freq_dist_filtered = FreqDist(c2a_false_filtered)

# Creates a dictionary with the frequency distribution of the classes
freq_dist_dict_filtered = {"C2A_true (filtered)": c2a_true_freq_dist_filtered, "C2A_false (filtered)": c2a_false_freq_dist_filtered}

# Plots the frequency distributions as a line plot
c2a_freq_dist_line_fig, c2a_freq_dist_line_ax = data_utils.create_frequency_distribution_line_plot(
    freq_dist_dict_filtered,
    title="C2A Frequency Word Distribution per Class (filtered)", 
    n_words=30,
    figsize=(16, 10),
    column_names=["Word", "Frequency"],
    show_grid=True
)
# Out:
# Creating class corpuses for C2A column...
#   - Found 6177 tweets for label 'False'
#   - Found 663 tweets for label 'True'
# Created 2 class corpuses successfully.
#   - C2A_false: ~139633 words
#   - C2A_true: ~23256 words
# Preparing text string for frequency distribution analysis...
# Text prepared successfully.
# Preparing text string for frequency distribution analysis...
# Text prepared successfully.
