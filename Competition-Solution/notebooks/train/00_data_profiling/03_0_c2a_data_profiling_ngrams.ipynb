# %%
# Competition-Solution/notebooks/train/00_data_profiling/03_0_c2a_data_profiling_ngrams.ipynb

# %% [markdown]
# ---

# %% [markdown]
# ##### <b>Imports</b>

# %%
import sys
from rich.console import Console

sys.path.append("../../../src")
import data_utils

console = Console()

# %% [markdown]
# ##### <b>Loading the data</b>

# %%
df_call2action, df_dbo, df_violence = data_utils.load_competition_data(data_dir="../../../data/raw/", type="train")
# Out:
# Loading competition data...
# Data of type 'train' loaded successfully.

# %% [markdown]
# ##### <b>N-Gram Frequency Distribution (C2A)</b>

# %% [markdown]
# <p>Initializing NLTK</p>

# %%
data_utils.initialize_nltk()
# Out:
# Initializing NLTK...
# Resources will be downloaded to /home/samuel/nltk_data.
# ...
# NLTK initialized successfully.

# %% [markdown]
# ---

# %% [markdown]
# <p><b>C2A n-gram Frequency Distribution (unfiltered)</b></p>
# <p><i><li>Bar Plot</li><i><p>

# %%
# Gets the class corpuses
c2a_class_corpuses = data_utils.get_class_corpuses(df_call2action, "C2A")

# Tokenizes the class corpuses
c2a_true_tokens, c2a_true_sentences = data_utils.prepare_text_for_frequency_distribution_analysis(
    c2a_class_corpuses["C2A_true"]
)
c2a_false_tokens, c2a_false_sentences = data_utils.prepare_text_for_frequency_distribution_analysis(
    c2a_class_corpuses["C2A_false"]
)

# Creates the n-gram frequency distributions for each class
c2a_true_bigram_freq = data_utils.generate_ngrams_from_tokens(c2a_true_tokens, n=2)
c2a_false_bigram_freq = data_utils.generate_ngrams_from_tokens(c2a_false_tokens, n=2)
c2a_true_trigram_freq = data_utils.generate_ngrams_from_tokens(c2a_true_tokens, n=3)
c2a_false_trigram_freq = data_utils.generate_ngrams_from_tokens(c2a_false_tokens, n=3)

# Creates a dictionary with the frequency distributions
ngram_freq_dict_unfiltered = {"C2A_true_bigram": c2a_true_bigram_freq, "C2A_false_bigram": c2a_false_bigram_freq, 
                              "C2A_true_trigram": c2a_true_trigram_freq, "C2A_false_trigram": c2a_false_trigram_freq}

# Plots the n-gram distributions as a bar plot
c2a_bigram_fig, c2a_bigram_ax = data_utils.create_ngram_frequency_plot(
    ngram_freq_dict_unfiltered,
    title="C2A n-gram Distribution per Class (unfiltered)", 
    n_items=20,
    figsize=(16, 10),
    show_grid=True
)
# Out:
# Creating class corpuses for C2A column...
#   - Found 6177 tweets for label 'False'
#   - Found 663 tweets for label 'True'
# Created 2 class corpuses successfully.
#   - C2A_false: ~139633 words
#   - C2A_true: ~23256 words
# Preparing text string for frequency distribution analysis...
# Text prepared successfully.
# Preparing text string for frequency distribution analysis...
# Text prepared successfully.
# Generating 2-grams from tokens...
# Generated 27581 2-grams successfully.
# Generating 2-grams from tokens...
# Generated 167468 2-grams successfully.
# Generating 3-grams from tokens...
# Generated 27580 3-grams successfully.
# Generating 3-grams from tokens...
# Generated 167467 3-grams successfully.
# Creating n-gram frequency distribution plot...
# N-gram frequency plot created successfully.

# %% [markdown]
# <p><i><li>Line Plot</li><i><p>

# %%
# Gets the class corpuses
c2a_class_corpuses = data_utils.get_class_corpuses(df_call2action, "C2A")

# Tokenizes the class corpuses
c2a_true_tokens, c2a_true_sentences = data_utils.prepare_text_for_frequency_distribution_analysis(
    c2a_class_corpuses["C2A_true"]
)
c2a_false_tokens, c2a_false_sentences = data_utils.prepare_text_for_frequency_distribution_analysis(
    c2a_class_corpuses["C2A_false"]
)

# Creates the n-gram frequency distributions for each class
c2a_true_bigram_freq = data_utils.generate_ngrams_from_tokens(c2a_true_tokens, n=2)
c2a_false_bigram_freq = data_utils.generate_ngrams_from_tokens(c2a_false_tokens, n=2)
c2a_true_trigram_freq = data_utils.generate_ngrams_from_tokens(c2a_true_tokens, n=3)
c2a_false_trigram_freq = data_utils.generate_ngrams_from_tokens(c2a_false_tokens, n=3)

# Creates a dictionary with the frequency distributions
ngram_freq_dict_unfiltered = {"C2A_true_bigram": c2a_true_bigram_freq, "C2A_false_bigram": c2a_false_bigram_freq, 
                              "C2A_true_trigram": c2a_true_trigram_freq, "C2A_false_trigram": c2a_false_trigram_freq}

# Plots the n-gram distributions as a line plot
c2a_ngram_line_fig, c2a_ngram_line_ax = data_utils.create_ngram_frequency_line_plot(
    ngram_freq_dict_unfiltered,
    title="C2A n-gram Distribution per Class (unfiltered)", 
    n_items=20,
    figsize=(16, 10),
    show_grid=True
)
# Out:
# Creating class corpuses for C2A column...
#   - Found 6177 tweets for label 'False'
#   - Found 663 tweets for label 'True'
# Created 2 class corpuses successfully.
#   - C2A_false: ~139633 words
#   - C2A_true: ~23256 words
# Preparing text string for frequency distribution analysis...
# Text prepared successfully.
# Preparing text string for frequency distribution analysis...
# Text prepared successfully.
# Generating 2-grams from tokens...
# Generated 27581 2-grams successfully.
# Generating 2-grams from tokens...
# Generated 167468 2-grams successfully.
# Generating 3-grams from tokens...
# Generated 27580 3-grams successfully.
# Generating 3-grams from tokens...
# Generated 167467 3-grams successfully.

# %% [markdown]
# <p><b>C2A n-gram Frequency Distribution (filtered)</b></p>
# <p><i><li>Bar Plot</li><i><p>

# %%
# Gets the class corpuses
c2a_class_corpuses = data_utils.get_class_corpuses(df_call2action, "C2A")

# Tokenizes the class corpuses
c2a_true_tokens, c2a_true_sentences = data_utils.prepare_text_for_frequency_distribution_analysis(
    c2a_class_corpuses["C2A_true"]
)
c2a_false_tokens, c2a_false_sentences = data_utils.prepare_text_for_frequency_distribution_analysis(
    c2a_class_corpuses["C2A_false"]
)

# Gets the filtered tokens
c2a_true_filtered = data_utils.get_filtered_tokens(c2a_true_tokens)
c2a_false_filtered = data_utils.get_filtered_tokens(c2a_false_tokens)

# Creates the filtered n-gram frequency distributions for each class
c2a_true_bigram_filtered_freq = data_utils.generate_ngrams_from_tokens(c2a_true_filtered, n=2)
c2a_false_bigram_filtered_freq = data_utils.generate_ngrams_from_tokens(c2a_false_filtered, n=2)
c2a_true_trigram_filtered_freq = data_utils.generate_ngrams_from_tokens(c2a_true_filtered, n=3)
c2a_false_trigram_filtered_freq = data_utils.generate_ngrams_from_tokens(c2a_false_filtered, n=3)

# Creates a dictionary with the filtered frequency distributions
ngram_freq_dict_filtered = {"C2A_true_bigram": c2a_true_bigram_filtered_freq, "C2A_false_bigram": c2a_false_bigram_filtered_freq,
                           "C2A_true_trigram": c2a_true_trigram_filtered_freq, "C2A_false_trigram": c2a_false_trigram_filtered_freq}

# Plots the filtered n-gram distributions as a bar plot
c2a_ngram_filtered_fig, c2a_ngram_filtered_ax = data_utils.create_ngram_frequency_plot(
    ngram_freq_dict_filtered,
    title="C2A n-gram Distribution per Class (filtered)", 
    n_items=20,
    figsize=(16, 10),
    show_grid=True
)
# Out:
# Creating class corpuses for C2A column...
#   - Found 6177 tweets for label 'False'
#   - Found 663 tweets for label 'True'
# Created 2 class corpuses successfully.
#   - C2A_false: ~139633 words
#   - C2A_true: ~23256 words
# Preparing text string for frequency distribution analysis...
# Text prepared successfully.
# Preparing text string for frequency distribution analysis...
# Text prepared successfully.
# Generating 2-grams from tokens...
# Generated 11645 2-grams successfully.
# Generating 2-grams from tokens...
# Generated 68065 2-grams successfully.
# Generating 3-grams from tokens...
# Generated 11644 3-grams successfully.
# Generating 3-grams from tokens...
# Generated 68064 3-grams successfully.
# Creating n-gram frequency distribution plot...
# N-gram frequency plot created successfully.

# %% [markdown]
# <p><i><li>Line Plot</li><i><p>

# %%
# Gets the class corpuses
c2a_class_corpuses = data_utils.get_class_corpuses(df_call2action, "C2A")

# Tokenizes the class corpuses
c2a_true_tokens, c2a_true_sentences = data_utils.prepare_text_for_frequency_distribution_analysis(
    c2a_class_corpuses["C2A_true"]
)
c2a_false_tokens, c2a_false_sentences = data_utils.prepare_text_for_frequency_distribution_analysis(
    c2a_class_corpuses["C2A_false"]
)

# Gets the filtered tokens
c2a_true_filtered = data_utils.get_filtered_tokens(c2a_true_tokens)
c2a_false_filtered = data_utils.get_filtered_tokens(c2a_false_tokens)

# Creates the filtered n-gram frequency distributions for each class
c2a_true_bigram_filtered_freq = data_utils.generate_ngrams_from_tokens(c2a_true_filtered, n=2)
c2a_false_bigram_filtered_freq = data_utils.generate_ngrams_from_tokens(c2a_false_filtered, n=2)
c2a_true_trigram_filtered_freq = data_utils.generate_ngrams_from_tokens(c2a_true_filtered, n=3)
c2a_false_trigram_filtered_freq = data_utils.generate_ngrams_from_tokens(c2a_false_filtered, n=3)

# Creates a dictionary with the filtered frequency distributions
ngram_freq_dict_filtered = {"C2A_true_bigram": c2a_true_bigram_filtered_freq, "C2A_false_bigram": c2a_false_bigram_filtered_freq,
                           "C2A_true_trigram": c2a_true_trigram_filtered_freq, "C2A_false_trigram": c2a_false_trigram_filtered_freq}

# Plots the filtered n-gram distributions as a line plot
c2a_ngram_filtered_line_fig, c2a_ngram_filtered_line_ax = data_utils.create_ngram_frequency_line_plot(
    ngram_freq_dict_filtered,
    title="C2A n-gram Distribution per Class (filtered)", 
    n_items=20,
    figsize=(16, 10),
    show_grid=True
)
# Out:
# Creating class corpuses for C2A column...
#   - Found 6177 tweets for label 'False'
#   - Found 663 tweets for label 'True'
# Created 2 class corpuses successfully.
#   - C2A_false: ~139633 words
#   - C2A_true: ~23256 words
# Preparing text string for frequency distribution analysis...
# Text prepared successfully.
# Preparing text string for frequency distribution analysis...
# Text prepared successfully.
# Generating 2-grams from tokens...
# Generated 11645 2-grams successfully.
# Generating 2-grams from tokens...
# Generated 68065 2-grams successfully.
# Generating 3-grams from tokens...
# Generated 11644 3-grams successfully.
# Generating 3-grams from tokens...
# Generated 68064 3-grams successfully.
