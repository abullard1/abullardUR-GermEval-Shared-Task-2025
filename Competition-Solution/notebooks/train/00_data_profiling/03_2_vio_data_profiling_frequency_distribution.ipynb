# %%
# Competition-Solution/notebooks/train/00_data_profiling/03_2_vio_data_profiling_frequency_distribution.ipynb

# %% [markdown]
# ---

# %% [markdown]
# ##### <b>Imports</b>

# %%
import sys
from nltk.probability import FreqDist
from rich.console import Console

sys.path.append("../../../src")
import data_utils

console = Console()

# %% [markdown]
# ##### <b>Loading the data</b>

# %%
df_call2action, df_dbo, df_violence = data_utils.load_competition_data(data_dir="../../../data/raw/", type="train")
# Out:
# Loading competition data...
# Data of type 'train' loaded successfully.

# %% [markdown]
# ##### <b>Frequency Distribution (VIO)</b>

# %% [markdown]
# <p>Initializing NLTK</p>

# %%
data_utils.initialize_nltk()
# Out:
# Initializing NLTK...
# Resources will be downloaded to /home/samuel/nltk_data.
# ...
# NLTK initialized successfully.

# %% [markdown]
# <p><b>Preparing the data for frequency distribution analysis</b></p>

# %%
vio_tokens, vio_sentences = data_utils.prepare_data_for_frequency_distribution_analysis(df_violence)
# Out:
# Preparing data for frequency distribution analysis...
# Preparing text string for frequency distribution analysis...
# Text prepared successfully.

# %% [markdown]
# ---

# %% [markdown]
# <p><b>VIO Frequency Distribution of the individual words (unfiltered)</b></p>

# %%
# Frequency Distribution of the individual tokens
vio_freq_dist_unfiltered = FreqDist(vio_tokens)

# Creates a dictionary with the frequency distribution of VIO
freq_dist_dict_unfiltered = {"VIO": vio_freq_dist_unfiltered}

# Plots the frequency distribution as a bar plot
vio_freq_dist_fig, vio_freq_dist_ax = data_utils.create_frequency_distribution_plot(
    freq_dist_dict_unfiltered,
    title="VIO Frequency Distribution of the individual words (unfiltered)", 
    n_words=30,
    figsize=(16, 10),
    column_names=["Word", "Frequency"],
    show_grid=True
)

# %% [markdown]
# <p><i><li>Line Plot</li><i><p>

# %%
# Frequency Distribution of the individual tokens
vio_freq_dist_unfiltered = FreqDist(vio_tokens)

# Creates a dictionary with the frequency distribution of VIO
freq_dist_dict_unfiltered = {"VIO": vio_freq_dist_unfiltered}

# Plots the frequency distribution as a line plot
vio_freq_dist_line_fig, vio_freq_dist_line_ax = data_utils.create_frequency_distribution_line_plot(
    freq_dist_dict_unfiltered,
    title="VIO Frequency Word Distribution (unfiltered)", 
    n_words=30,
    figsize=(16, 10),
    column_names=["Word", "Frequency"],
    show_grid=True
)

# %% [markdown]
# <p><b>VIO Frequency Distribution of the individual words (filtered)</b></p>
# <p><i><li>Bar Plot</li><i><p>

# %%
# Removes stopwords from the tokens
vio_filtered_words = data_utils.get_filtered_tokens(vio_tokens)

# Frequency Distribution of the individual tokens
vio_freq_dist_filtered = FreqDist(vio_filtered_words)

# Creates a dictionary with the frequency distribution of VIO
freq_dist_dict_filtered = {"VIO": vio_freq_dist_filtered}

# Plots the frequency distribution as a bar plot
vio_freq_dist_fig, vio_freq_dist_ax = data_utils.create_frequency_distribution_plot(
    freq_dist_dict_filtered,
    title="VIO Frequency Word Distribution (filtered)", 
    n_words=30,
    figsize=(16, 10),
    column_names=["Word", "Frequency"],
    show_grid=True
)

# %% [markdown]
# <p><b>VIO Frequency Distribution of the individual words (filtered)</b></p>
# <p><i><li>Line Plot</li><i><p>

# %%
# Removes stopwords from the tokens
vio_filtered_words = data_utils.get_filtered_tokens(vio_tokens)

# Frequency Distribution of the individual tokens
vio_freq_dist_filtered = FreqDist(vio_filtered_words)

# Creates a dictionary with the frequency distribution of VIO
freq_dist_dict_filtered = {"VIO": vio_freq_dist_filtered}

# Plots the frequency distribution as a line plot
vio_freq_dist_line_fig, vio_freq_dist_line_ax = data_utils.create_frequency_distribution_line_plot(
    freq_dist_dict_filtered,
    title="VIO Frequency Word Distribution (filtered)", 
    n_words=30,
    figsize=(16, 10),
    column_names=["Word", "Frequency"],
    show_grid=True
)

# %% [markdown]
# ---

# %% [markdown]
# <p><b>VIO Per Class Frequency Distribution of the individual words (unfiltered)</b></p>
# <p><i><li>Bar Plot</li><i><p>

# %%
# Gets the class corpuses
vio_class_corpuses = data_utils.get_class_corpuses(df_violence, "VIO")

# Tokenizes the class corpuses
vio_true_tokens, vio_true_sentences = data_utils.prepare_text_for_frequency_distribution_analysis(
    vio_class_corpuses["VIO_true"]
)
vio_false_tokens, vio_false_sentences = data_utils.prepare_text_for_frequency_distribution_analysis(
    vio_class_corpuses["VIO_false"]
)

# Creates the frequency distribution classes
vio_true_freq_dist = FreqDist(vio_true_tokens)
vio_false_freq_dist = FreqDist(vio_false_tokens)

# Creates a dictionary with the frequency distribution of the classes
freq_dist_dict_unfiltered = {"VIO_true": vio_true_freq_dist, "VIO_false": vio_false_freq_dist}

# Plots the frequency distributions as a bar plot
vio_freq_dist_fig, vio_freq_dist_ax = data_utils.create_frequency_distribution_plot(
    freq_dist_dict_unfiltered,
    title="VIO Frequency Word Distribution per Class (unfiltered)", 
    n_words=30,
    figsize=(16, 10),
    column_names=["Word", "Frequency"],
    show_grid=True
)
# Out:
# Creating class corpuses for VIO column...
#   - Found 7219 tweets for label 'False'
#   - Found 564 tweets for label 'True'
# Created 2 class corpuses successfully.
#   - VIO_false: ~170263 words
#   - VIO_true: ~16928 words
# Preparing text string for frequency distribution analysis...
# Text prepared successfully.
# Preparing text string for frequency distribution analysis...
# Text prepared successfully.

# %% [markdown]
# <p><i><li>Line Plot</li><i><p>

# %%
# Gets the class corpuses for the data
vio_class_corpuses = data_utils.get_class_corpuses(df_violence, "VIO")

# Tokenizes the class corpuses
vio_true_tokens, vio_true_sentences = data_utils.prepare_text_for_frequency_distribution_analysis(
    vio_class_corpuses["VIO_true"]
)
vio_false_tokens, vio_false_sentences = data_utils.prepare_text_for_frequency_distribution_analysis(
    vio_class_corpuses["VIO_false"]
)

# Creates the frequency distribution classes
vio_true_freq_dist = FreqDist(vio_true_tokens)
vio_false_freq_dist = FreqDist(vio_false_tokens)

# Creates a dictionary with the frequency distributions
freq_dist_dict_unfiltered = {"VIO_true": vio_true_freq_dist, "VIO_false": vio_false_freq_dist}

# Plots the frequency distribution as a line plot
vio_freq_dist_line_fig, vio_freq_dist_line_ax = data_utils.create_frequency_distribution_line_plot(
    freq_dist_dict_unfiltered,
    title="VIO Frequency Word Distribution per Class (unfiltered)", 
    n_words=30,
    figsize=(16, 10),
    column_names=["Word", "Frequency"],
    show_grid=True
)
# Out:
# Creating class corpuses for VIO column...
#   - Found 7219 tweets for label 'False'
#   - Found 564 tweets for label 'True'
# Created 2 class corpuses successfully.
#   - VIO_false: ~170263 words
#   - VIO_true: ~16928 words
# Preparing text string for frequency distribution analysis...
# Text prepared successfully.
# Preparing text string for frequency distribution analysis...
# Text prepared successfully.

# %% [markdown]
# <p><b>VIO Per Class Frequency Distribution of the individual words (filtered)</b></p>
# <p><i><li>Bar Plot</li><i><p>

# %%
# Gets the class corpuses for the data
vio_class_corpuses = data_utils.get_class_corpuses(df_violence, "VIO")

# Tokenizes the class corpuses
vio_true_tokens, vio_true_sentences = data_utils.prepare_text_for_frequency_distribution_analysis(
    vio_class_corpuses["VIO_true"]
)
vio_false_tokens, vio_false_sentences = data_utils.prepare_text_for_frequency_distribution_analysis(
    vio_class_corpuses["VIO_false"]
)

# Removes stopwords from the tokens
vio_true_filtered = data_utils.get_filtered_tokens(vio_true_tokens)
vio_false_filtered = data_utils.get_filtered_tokens(vio_false_tokens)

# Creates the frequency distribution classes
vio_true_freq_dist_filtered = FreqDist(vio_true_filtered)
vio_false_freq_dist_filtered = FreqDist(vio_false_filtered)

# Creates a dictionary with the frequency distribution of the classes
freq_dist_dict_filtered = {"VIO_true (filtered)": vio_true_freq_dist_filtered, "VIO_false (filtered)": vio_false_freq_dist_filtered}

# Plots the frequency distributions as a bar plot
vio_filtered_freq_dist_fig, vio_filtered_freq_dist_ax = data_utils.create_frequency_distribution_plot(
    freq_dist_dict_filtered,
    title="VIO Frequency Word Distribution per Class (filtered)", 
    n_words=30,
    figsize=(16, 10),
    column_names=["Word", "Frequency"],
    show_grid=True
)
# Out:
# Creating class corpuses for VIO column...
#   - Found 7219 tweets for label 'False'
#   - Found 564 tweets for label 'True'
# Created 2 class corpuses successfully.
#   - VIO_false: ~170263 words
#   - VIO_true: ~16928 words
# Preparing text string for frequency distribution analysis...
# Text prepared successfully.
# Preparing text string for frequency distribution analysis...
# Text prepared successfully.

# %% [markdown]
# <p><i><li>Line Plot</li><i><p>

# %%
# Gets the class corpuses for the data
vio_class_corpuses = data_utils.get_class_corpuses(df_violence, "VIO")

# Tokenizes the class corpuses
vio_true_tokens, vio_true_sentences = data_utils.prepare_text_for_frequency_distribution_analysis(
    vio_class_corpuses["VIO_true"]
)
vio_false_tokens, vio_false_sentences = data_utils.prepare_text_for_frequency_distribution_analysis(
    vio_class_corpuses["VIO_false"]
)

# Removes stopwords from the tokens
vio_true_filtered = data_utils.get_filtered_tokens(vio_true_tokens)
vio_false_filtered = data_utils.get_filtered_tokens(vio_false_tokens)

# Creates the frequency distribution classes
vio_true_freq_dist_filtered = FreqDist(vio_true_filtered)
vio_false_freq_dist_filtered = FreqDist(vio_false_filtered)

# Creates a dictionary with the frequency distribution of the classes
freq_dist_dict_filtered = {"VIO_true (filtered)": vio_true_freq_dist_filtered, "VIO_false (filtered)": vio_false_freq_dist_filtered}

# Plots the frequency distributions as a bar plot
vio_freq_dist_line_fig, vio_freq_dist_line_ax = data_utils.create_frequency_distribution_line_plot(
    freq_dist_dict_filtered,
    title="VIO Frequency Word Distribution per Class (filtered)", 
    n_words=30,
    figsize=(16, 10),
    column_names=["Word", "Frequency"],
    show_grid=True
)
# Out:
# Creating class corpuses for VIO column...
#   - Found 7219 tweets for label 'False'
#   - Found 564 tweets for label 'True'
# Created 2 class corpuses successfully.
#   - VIO_false: ~170263 words
#   - VIO_true: ~16928 words
# Preparing text string for frequency distribution analysis...
# Text prepared successfully.
# Preparing text string for frequency distribution analysis...
# Text prepared successfully.
