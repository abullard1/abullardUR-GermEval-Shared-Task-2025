# %%
# Competition-Solution/notebooks/train/00_data_profiling/03_1_dbo_data_profiling_frequency_distribution.ipynb

# %% [markdown]
# ---

# %% [markdown]
# ##### <b>Imports</b>

# %%
import sys
from nltk.probability import FreqDist
from rich.console import Console

sys.path.append("../../../src")
import data_utils

console = Console()

# %% [markdown]
# ##### <b>Loading the data</b>

# %%
df_call2action, df_dbo, df_violence = data_utils.load_competition_data(data_dir="../../../data/raw/", type="train")
# Out:
# Loading competition data...
# Data of type 'train' loaded successfully.

# %% [markdown]
# ##### <b>Frequency Distribution (DBO)</b>

# %% [markdown]
# <p>Initializing NLTK</p>

# %%
data_utils.initialize_nltk()
# Out:
# Initializing NLTK...
# Resources will be downloaded to /home/samuel/nltk_data.
# ...
# NLTK initialized successfully.

# %% [markdown]
# <p><b>Preparing the data for frequency distribution analysis</b></p>

# %%
dbo_tokens, dbo_sentences = data_utils.prepare_data_for_frequency_distribution_analysis(df_dbo)
# Out:
# Preparing data for frequency distribution analysis...
# Preparing text string for frequency distribution analysis...
# Text prepared successfully.

# %% [markdown]
# ---

# %% [markdown]
# <p><b>DBO Frequency Distribution of the individual words (unfiltered)</b></p>

# %%
# Frequency Distribution of the individual tokens
dbo_freq_dist_unfiltered = FreqDist(dbo_tokens)

# Creates a dictionary with the frequency distribution of DBO
freq_dist_dict_unfiltered = {"DBO": dbo_freq_dist_unfiltered}

# Plots the frequency distribution as a bar plot
dbo_freq_dist_fig, dbo_freq_dist_ax = data_utils.create_frequency_distribution_plot(
    freq_dist_dict_unfiltered,
    title="DBO Frequency Distribution of the individual words (unfiltered)", 
    n_words=30,
    figsize=(16, 10),
    column_names=["Word", "Frequency"],
    show_grid=True
)

# %% [markdown]
# <p><i><li>Line Plot</li><i><p>

# %%
# Frequency Distribution of the individual tokens
dbo_freq_dist_unfiltered = FreqDist(dbo_tokens)

# Creates a dictionary with the frequency distribution of DBO
freq_dist_dict_unfiltered = {"DBO": dbo_freq_dist_unfiltered}

# Plots the frequency distribution as a line plot
dbo_freq_dist_line_fig, dbo_freq_dist_line_ax = data_utils.create_frequency_distribution_line_plot(
    freq_dist_dict_unfiltered,
    title="DBO Frequency Word Distribution (unfiltered)", 
    n_words=30,
    figsize=(16, 10),
    column_names=["Word", "Frequency"],
    show_grid=True
)

# %% [markdown]
# <p><b>DBO Frequency Distribution of the individual words (filtered)</b></p>
# <p><i><li>Bar Plot</li><i><p>

# %%
# Removes stopwords from the tokens
dbo_filtered_words = data_utils.get_filtered_tokens(dbo_tokens)

# Frequency Distribution of the individual tokens
dbo_freq_dist_filtered = FreqDist(dbo_filtered_words)

# Creates a dictionary with the frequency distribution of DBO
freq_dist_dict_filtered = {"DBO": dbo_freq_dist_filtered}

# Plots the frequency distribution as a bar plot
dbo_freq_dist_fig, dbo_freq_dist_ax = data_utils.create_frequency_distribution_plot(
    freq_dist_dict_filtered,
    title="DBO Frequency Word Distribution (filtered)", 
    n_words=30,
    figsize=(16, 10),
    column_names=["Word", "Frequency"],
    show_grid=True
)

# %% [markdown]
# <p><b>DBO Frequency Distribution of the individual words (filtered)</b></p>
# <p><i><li>Line Plot</li><i><p>

# %%
# Removes stopwords from the tokens
dbo_filtered_words = data_utils.get_filtered_tokens(dbo_tokens)

# Frequency Distribution of the individual tokens
dbo_freq_dist_filtered = FreqDist(dbo_filtered_words)

# Creates a dictionary with the frequency distribution of DBO
freq_dist_dict_filtered = {"DBO": dbo_freq_dist_filtered}

# Plots the frequency distribution as a line plot
dbo_freq_dist_line_fig, dbo_freq_dist_line_ax = data_utils.create_frequency_distribution_line_plot(
    freq_dist_dict_filtered,
    title="DBO Frequency Word Distribution (filtered)", 
    n_words=30,
    figsize=(16, 10),
    column_names=["Word", "Frequency"],
    show_grid=True
)

# %% [markdown]
# ---

# %% [markdown]
# <p><b>DBO Per Class Frequency Distribution of the individual words (unfiltered)</b></p>
# <p><i><li>Bar Plot</li><i><p>

# %%
# Gets the class corpuses
dbo_class_corpuses = data_utils.get_class_corpuses(df_dbo, "DBO")

# Tokenizes the class corpuses
dbo_nothing_tokens, dbo_nothing_sentences = data_utils.prepare_text_for_frequency_distribution_analysis(
    dbo_class_corpuses["DBO_nothing"]
)
dbo_criticism_tokens, dbo_criticism_sentences = data_utils.prepare_text_for_frequency_distribution_analysis(
    dbo_class_corpuses["DBO_criticism"]
)
dbo_subversive_tokens, dbo_subversive_sentences = data_utils.prepare_text_for_frequency_distribution_analysis(
    dbo_class_corpuses["DBO_subversive"]
)
dbo_agitation_tokens, dbo_agitation_sentences = data_utils.prepare_text_for_frequency_distribution_analysis(
    dbo_class_corpuses["DBO_agitation"]
)

# Creates the frequency distribution classes
dbo_nothing_freq_dist = FreqDist(dbo_nothing_tokens)
dbo_criticism_freq_dist = FreqDist(dbo_criticism_tokens)
dbo_subversive_freq_dist = FreqDist(dbo_subversive_tokens)
dbo_agitation_freq_dist = FreqDist(dbo_agitation_tokens)

# Creates a dictionary with the frequency distribution of the classes
freq_dist_dict_unfiltered = {"DBO_nothing": dbo_nothing_freq_dist, "DBO_criticism": dbo_criticism_freq_dist, "DBO_subversive": dbo_subversive_freq_dist, "DBO_agitation": dbo_agitation_freq_dist}

# Plots the frequency distributions as a bar plot
dbo_freq_dist_fig, dbo_freq_dist_ax = data_utils.create_frequency_distribution_plot(
    freq_dist_dict_unfiltered,
    title="DBO Frequency Word Distribution per Class (unfiltered)", 
    n_words=30,
    figsize=(16, 10),
    column_names=["Word", "Frequency"],
    show_grid=True
)
# Out:
# Creating class corpuses for DBO column...
#   - Found 6277 tweets for label 'nothing'
#   - Found 804 tweets for label 'criticism'
#   - Found 60 tweets for label 'subversive'
#   - Found 313 tweets for label 'agitation'
# Created 4 class corpuses successfully.
#   - DBO_nothing: ~114091 words
#   - DBO_criticism: ~40804 words
#   - DBO_subversive: ~2148 words
#   - DBO_agitation: ~8830 words
# Preparing text string for frequency distribution analysis...
# Text prepared successfully.
# Preparing text string for frequency distribution analysis...
# Text prepared successfully.
# Preparing text string for frequency distribution analysis...
# Text prepared successfully.
# Preparing text string for frequency distribution analysis...
# Text prepared successfully.

# %% [markdown]
# <p><i><li>Line Plot</li><i><p>

# %%
# Gets the class corpuses
dbo_class_corpuses = data_utils.get_class_corpuses(df_dbo, "DBO")

# Tokenizes the class corpuses
dbo_nothing_tokens, dbo_nothing_sentences = data_utils.prepare_text_for_frequency_distribution_analysis(
    dbo_class_corpuses["DBO_nothing"]
)
dbo_criticism_tokens, dbo_criticism_sentences = data_utils.prepare_text_for_frequency_distribution_analysis(
    dbo_class_corpuses["DBO_criticism"]
)
dbo_subversive_tokens, dbo_subversive_sentences = data_utils.prepare_text_for_frequency_distribution_analysis(
    dbo_class_corpuses["DBO_subversive"]
)
dbo_agitation_tokens, dbo_agitation_sentences = data_utils.prepare_text_for_frequency_distribution_analysis(
    dbo_class_corpuses["DBO_agitation"]
)

# Creates the frequency distribution classes
dbo_nothing_freq_dist = FreqDist(dbo_nothing_tokens)
dbo_criticism_freq_dist = FreqDist(dbo_criticism_tokens)
dbo_subversive_freq_dist = FreqDist(dbo_subversive_tokens)
dbo_agitation_freq_dist = FreqDist(dbo_agitation_tokens)

# Creates a dictionary with the frequency distributions
freq_dist_dict_unfiltered = {"DBO_nothing": dbo_nothing_freq_dist, "DBO_criticism": dbo_criticism_freq_dist, "DBO_subversive": dbo_subversive_freq_dist, "DBO_agitation": dbo_agitation_freq_dist}

# Plots the frequency distribution as a line plot
dbo_freq_dist_line_fig, dbo_freq_dist_line_ax = data_utils.create_frequency_distribution_line_plot(
    freq_dist_dict_unfiltered,
    title="DBO Frequency Word Distribution per Class (unfiltered)", 
    n_words=30,
    figsize=(16, 10),
    column_names=["Word", "Frequency"],
    show_grid=True
)
# Out:
# Creating class corpuses for DBO column...
#   - Found 6277 tweets for label 'nothing'
#   - Found 804 tweets for label 'criticism'
#   - Found 60 tweets for label 'subversive'
#   - Found 313 tweets for label 'agitation'
# Created 4 class corpuses successfully.
#   - DBO_nothing: ~114091 words
#   - DBO_criticism: ~40804 words
#   - DBO_subversive: ~2148 words
#   - DBO_agitation: ~8830 words
# Preparing text string for frequency distribution analysis...
# Text prepared successfully.
# Preparing text string for frequency distribution analysis...
# Text prepared successfully.
# Preparing text string for frequency distribution analysis...
# Text prepared successfully.
# Preparing text string for frequency distribution analysis...
# Text prepared successfully.

# %% [markdown]
# <p><b>DBO Per Class Frequency Distribution of the individual words (filtered)</b></p>
# <p><i><li>Bar Plot</li><i><p>

# %%
# Gets the class corpuses
dbo_class_corpuses = data_utils.get_class_corpuses(df_dbo, "DBO")

# Tokenizes the class corpuses
dbo_nothing_tokens, dbo_nothing_sentences = data_utils.prepare_text_for_frequency_distribution_analysis(
    dbo_class_corpuses["DBO_nothing"]
)
dbo_criticism_tokens, dbo_criticism_sentences = data_utils.prepare_text_for_frequency_distribution_analysis(
    dbo_class_corpuses["DBO_criticism"]
)
dbo_subversive_tokens, dbo_subversive_sentences = data_utils.prepare_text_for_frequency_distribution_analysis(
    dbo_class_corpuses["DBO_subversive"]
)
dbo_agitation_tokens, dbo_agitation_sentences = data_utils.prepare_text_for_frequency_distribution_analysis(
    dbo_class_corpuses["DBO_agitation"]
)

# Removes stopwords from the tokens
dbo_nothing_filtered = data_utils.get_filtered_tokens(dbo_nothing_tokens)
dbo_criticism_filtered = data_utils.get_filtered_tokens(dbo_criticism_tokens)
dbo_subversive_filtered = data_utils.get_filtered_tokens(dbo_subversive_tokens)
dbo_agitation_filtered = data_utils.get_filtered_tokens(dbo_agitation_tokens)

# Creates the frequency distribution classes
dbo_nothing_freq_dist_filtered = FreqDist(dbo_nothing_filtered)
dbo_criticism_freq_dist_filtered = FreqDist(dbo_criticism_filtered)
dbo_subversive_freq_dist_filtered = FreqDist(dbo_subversive_filtered)
dbo_agitation_freq_dist_filtered = FreqDist(dbo_agitation_filtered)

# Creates a dictionary with the frequency distribution of the classes
freq_dist_dict_filtered = {"DBO_nothing (filtered)": dbo_nothing_freq_dist_filtered, "DBO_criticism (filtered)": dbo_criticism_freq_dist_filtered, "DBO_subversive (filtered)": dbo_subversive_freq_dist_filtered, "DBO_agitation (filtered)": dbo_agitation_freq_dist_filtered}

# Plots the frequency distributions as a bar plot
dbo_filtered_freq_dist_fig, dbo_filtered_freq_dist_ax = data_utils.create_frequency_distribution_plot(
    freq_dist_dict_filtered,
    title="DBO Frequency Word Distribution per Class (filtered)", 
    n_words=30,
    figsize=(16, 10),
    column_names=["Word", "Frequency"],
    show_grid=True
)
# Out:
# Creating class corpuses for DBO column...
#   - Found 6277 tweets for label 'nothing'
#   - Found 804 tweets for label 'criticism'
#   - Found 60 tweets for label 'subversive'
#   - Found 313 tweets for label 'agitation'
# Created 4 class corpuses successfully.
#   - DBO_nothing: ~114091 words
#   - DBO_criticism: ~40804 words
#   - DBO_subversive: ~2148 words
#   - DBO_agitation: ~8830 words
# Preparing text string for frequency distribution analysis...
# Text prepared successfully.
# Preparing text string for frequency distribution analysis...
# Text prepared successfully.
# Preparing text string for frequency distribution analysis...
# Text prepared successfully.
# Preparing text string for frequency distribution analysis...
# Text prepared successfully.

# %% [markdown]
# <p><i><li>Line Plot</li><i><p>

# %%
# Gets the class corpuses
dbo_class_corpuses = data_utils.get_class_corpuses(df_dbo, "DBO")

# Tokenizes the class corpuses
dbo_nothing_tokens, dbo_nothing_sentences = data_utils.prepare_text_for_frequency_distribution_analysis(
    dbo_class_corpuses["DBO_nothing"]
)
dbo_criticism_tokens, dbo_criticism_sentences = data_utils.prepare_text_for_frequency_distribution_analysis(
    dbo_class_corpuses["DBO_criticism"]
)
dbo_subversive_tokens, dbo_subversive_sentences = data_utils.prepare_text_for_frequency_distribution_analysis(
    dbo_class_corpuses["DBO_subversive"]
)
dbo_agitation_tokens, dbo_agitation_sentences = data_utils.prepare_text_for_frequency_distribution_analysis(
    dbo_class_corpuses["DBO_agitation"]
)

# Removes stopwords from the tokens
dbo_nothing_filtered = data_utils.get_filtered_tokens(dbo_nothing_tokens)
dbo_criticism_filtered = data_utils.get_filtered_tokens(dbo_criticism_tokens)
dbo_subversive_filtered = data_utils.get_filtered_tokens(dbo_subversive_tokens)
dbo_agitation_filtered = data_utils.get_filtered_tokens(dbo_agitation_tokens)

# Creates the frequency distribution classes
dbo_nothing_freq_dist_filtered = FreqDist(dbo_nothing_filtered)
dbo_criticism_freq_dist_filtered = FreqDist(dbo_criticism_filtered)
dbo_subversive_freq_dist_filtered = FreqDist(dbo_subversive_filtered)
dbo_agitation_freq_dist_filtered = FreqDist(dbo_agitation_filtered)

# Creates a dictionary with the frequency distribution of the classes
freq_dist_dict_filtered = {"DBO_nothing (filtered)": dbo_nothing_freq_dist_filtered, "DBO_criticism (filtered)": dbo_criticism_freq_dist_filtered, "DBO_subversive (filtered)": dbo_subversive_freq_dist_filtered, "DBO_agitation (filtered)": dbo_agitation_freq_dist_filtered}

# Plots the frequency distribution as a line plot
dbo_freq_dist_line_fig, dbo_freq_dist_line_ax = data_utils.create_frequency_distribution_line_plot(
    freq_dist_dict_filtered,
    title="DBO Frequency Word Distribution per Class (filtered)", 
    n_words=30,
    figsize=(16, 10),
    column_names=["Word", "Frequency"],
    show_grid=True
)
# Out:
# Creating class corpuses for DBO column...
#   - Found 6277 tweets for label 'nothing'
#   - Found 804 tweets for label 'criticism'
#   - Found 60 tweets for label 'subversive'
#   - Found 313 tweets for label 'agitation'
# Created 4 class corpuses successfully.
#   - DBO_nothing: ~114091 words
#   - DBO_criticism: ~40804 words
#   - DBO_subversive: ~2148 words
#   - DBO_agitation: ~8830 words
# Preparing text string for frequency distribution analysis...
# Text prepared successfully.
# Preparing text string for frequency distribution analysis...
# Text prepared successfully.
# Preparing text string for frequency distribution analysis...
# Text prepared successfully.
# Preparing text string for frequency distribution analysis...
# Text prepared successfully.
